# %%
# Código Completo

import pyautogui
import time
import openpyxl

#Abrir navegador
pyautogui.press('win')
time.sleep(1)
pyautogui.write('Chrome')
time.sleep(1)
pyautogui.press('Enter')
time.sleep(2)
#pyautogui.hotkey('win', 'up')
time.sleep(1)

#Acessar NewCon
pyautogui.write('https://newcon.bancorbras.com.br/intranet/')
time.sleep(1)
pyautogui.press('Enter')
time.sleep(2)
pyautogui.press('tab', presses=2)
time.sleep(1)
pyautogui.press('Enter')
time.sleep(3)

#Unidade de negócio
x, y, largura, altura = pyautogui.locateOnScreen('unidade.png', grayscale= True, confidence= 0.7)
time.sleep(1)
pyautogui.click(x + largura/2, y + altura/2)
time.sleep(3)

#Importanto a planilha.
workbook = openpyxl.load_workbook('extrato.xlsx')
#Indicando qual aba eu quero utilizar.
pagina_clientes = workbook['Plan1']
#Informando qual a primeira linha de leitura
for linha in pagina_clientes.iter_rows(min_row=2):
    grupo = linha [0].value
    cota = linha[1].value
    nome = linha[2].value

    #Atendimento
    x, y, largura, altura = pyautogui.locateOnScreen('atendimento.png', grayscale= True, confidence= 0.7)
    time.sleep(1)
    pyautogui.click(x + largura/2, y + altura/2)
    time.sleep(1)

    #Grupo:
    time.sleep(3)
    pyautogui.write(str(grupo))
    time.sleep(1)
    pyautogui.press('tab')
    time.sleep(2)

    #Cota:
    pyautogui.write(str(cota))
    time.sleep(1)
    pyautogui.press('tab', presses=2)
    time.sleep(1)
    pyautogui.press('Enter')
    time.sleep(6)
    pyautogui.press('tab', presses=20)
    time.sleep(1)
    pyautogui.press('Enter')
    time.sleep(1)
    pyautogui.scroll(-500)
    time.sleep(2)   

    #Mensagens
    x, y, largura, altura = pyautogui.locateOnScreen('mensagens.png', grayscale= True, confidence= 0.7)
    time.sleep(1)
    pyautogui.click(x + largura/2, y + altura/2)
    time.sleep(3) 
    pyautogui.scroll(-500)
    time.sleep(2) 

    #Imprimir
    x, y, largura, altura = pyautogui.locateOnScreen('imprimir.png', grayscale= True, confidence= 0.7)
    time.sleep(1)
    pyautogui.click(x + largura/2, y + altura/2)
    time.sleep(2)

    #Extrato Atualizado
    x, y, largura, altura = pyautogui.locateOnScreen('extrato_atualizado.png', grayscale= True, confidence= 0.7)
    time.sleep(1)
    pyautogui.click(x + largura/2, y + altura/2)
    time.sleep(4    )
    pyautogui.press('esc')
    time.sleep(3)
    

    #Imprimir
    pyautogui.hotkey('win', 'up')
    time.sleep(5)
    pyautogui.press('tab', presses=6)
    time.sleep(2)
    pyautogui.press('enter')
    time.sleep(2)
    pyautogui.press('enter')
    time.sleep(4)

    #Renomear Arquivo
    pyautogui.write(str(grupo))
    time.sleep(1)
    pyautogui.write('-')
    time.sleep(1)
    pyautogui.write(str(cota))
    time.sleep(1)
    pyautogui.press('enter')
    time.sleep(4)

    #Fechar
    pyautogui.hotkey('alt', 'f4')
    time.sleep(2)
    x, y, largura, altura = pyautogui.locateOnScreen('fechar.png', grayscale= True, confidence= 0.7)
    time.sleep(1)
    pyautogui.click(x + largura/2, y + altura/2)
    time.sleep(1)
# Out:
# ---------------------------------------------------------------------------
# ImageNotFoundException                    Traceback (most recent call last)
# File c:\Users\raleixo1992\Desktop\Projetos Python\update_processos\Lib\site-packages\pyautogui\__init__.py:172, in raisePyAutoGUIImageNotFoundException.<locals>.wrapper(*args, **kwargs)
#     171 try:
# --> 172     return wrappedFunction(*args, **kwargs)
#     173 except pyscreeze.ImageNotFoundException:
#
# File c:\Users\raleixo1992\Desktop\Projetos Python\update_processos\Lib\site-packages\pyautogui\__init__.py:210, in locateOnScreen(*args, **kwargs)
#     208 @raisePyAutoGUIImageNotFoundException
#     209 def locateOnScreen(*args, **kwargs):
# --> 210     return pyscreeze.locateOnScreen(*args, **kwargs)
#
# File c:\Users\raleixo1992\Desktop\Projetos Python\update_processos\Lib\site-packages\pyscreeze\__init__.py:405, in locateOnScreen(image, minSearchTime, **kwargs)
#     404 screenshotIm = screenshot(region=None)
# --> 405 retVal = locate(image, screenshotIm, **kwargs)
#     406 try:
#
# File c:\Users\raleixo1992\Desktop\Projetos Python\update_processos\Lib\site-packages\pyscreeze\__init__.py:383, in locate(needleImage, haystackImage, **kwargs)
#     382 kwargs['limit'] = 1
# --> 383 points = tuple(locateAll(needleImage, haystackImage, **kwargs))
#     384 if len(points) > 0:
#
# File c:\Users\raleixo1992\Desktop\Projetos Python\update_processos\Lib\site-packages\pyscreeze\__init__.py:257, in _locateAll_opencv(needleImage, haystackImage, grayscale, limit, region, step, confidence)
#     256 if USE_IMAGE_NOT_FOUND_EXCEPTION:
# --> 257     raise ImageNotFoundException('Could not locate the image (highest confidence = %.3f)' % result.max())
#     258 else:
#
# ImageNotFoundException: Could not locate the image (highest confidence = 0.538)
#
# During handling of the above exception, another exception occurred:
#
# ImageNotFoundException                    Traceback (most recent call last)
# Cell In[21], line 85
#      82 time.sleep(2)
#      84 #Extrato Atualizado
# ---> 85 x, y, largura, altura = pyautogui.locateOnScreen('extrato_atualizado.png', grayscale= True, confidence= 0.7)
#      86 time.sleep(1)
#      87 pyautogui.click(x + largura/2, y + altura/2)
#
# File c:\Users\raleixo1992\Desktop\Projetos Python\update_processos\Lib\site-packages\pyautogui\__init__.py:174, in raisePyAutoGUIImageNotFoundException.<locals>.wrapper(*args, **kwargs)
#     172     return wrappedFunction(*args, **kwargs)
#     173 except pyscreeze.ImageNotFoundException:
# --> 174     raise ImageNotFoundException
#
# ImageNotFoundException:

# %% [markdown]
# https://newcon.bancorbras.com.br/intranet/
